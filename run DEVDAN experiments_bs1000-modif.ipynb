# %%
# %run DEVDAN_creditcarddefault.ipynb
# Out:
# Number of input:  24
# Number of output:  2
# Number of batch:  30
# All Data
# 100% (30 of 30) |########################| Elapsed Time: 0:01:08 ETA:  00:00:00
# === Performance result ===
# Accuracy:  80.36206896551725 (+/-) 2.35977991275099
# Precision:  0.7802580841810538
# Recall:  0.8036206896551724
# F1 score:  0.7680939866637828
# Testing Time:  0.0027776339958454 (+/-) 0.000757429125174388
# Training Time:  2.367788520352594 (+/-) 0.2923067882250773
#
#
# === Average network evolution ===
# Total hidden node:  25.533333333333335 (+/-) 0.5617433182117573
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=24, out_features=26, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 24
# No. of nodes : 26
# No. of parameters : 674
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=26, out_features=2, bias=True)
# )
# No. of inputs : 26
# No. of output : 2
# No. of parameters : 54
# 100% (30 of 30) |########################| Elapsed Time: 0:01:25 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.65172413793104 (+/-) 9.015718866652886
# Precision:  0.7481913064703313
# Recall:  0.7765172413793103
# F1 score:  0.7553615948570607
# Testing Time:  0.0026763965343606882 (+/-) 0.0004609703096092471
# Training Time:  2.9312448748226823 (+/-) 0.4538841026374429
#
#
# === Average network evolution ===
# Total hidden node:  24.566666666666666 (+/-) 0.5587684871413404
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=24, out_features=25, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 24
# No. of nodes : 25
# No. of parameters : 649
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=25, out_features=2, bias=True)
# )
# No. of inputs : 25
# No. of output : 2
# No. of parameters : 52
# 100% (30 of 30) |########################| Elapsed Time: 0:01:42 ETA:  00:00:00
# === Performance result ===
# Accuracy:  79.93793103448277 (+/-) 2.7786642527888326
# Precision:  0.7728358744108839
# Recall:  0.7993793103448276
# F1 score:  0.765597331480301
# Testing Time:  0.0027518025759992928 (+/-) 0.0005618940718525518
# Training Time:  3.51483207735522 (+/-) 0.559179059503675
#
#
# === Average network evolution ===
# Total hidden node:  28.133333333333333 (+/-) 4.681405297082869
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=24, out_features=30, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 24
# No. of nodes : 30
# No. of parameters : 774
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=30, out_features=2, bias=True)
# )
# No. of inputs : 30
# No. of output : 2
# No. of parameters : 62
# 100% (30 of 30) |########################| Elapsed Time: 0:01:19 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.84827586206896 (+/-) 8.810049930957776
# Precision:  0.7566784996544272
# Recall:  0.7884827586206896
# F1 score:  0.7571756684257505
# Testing Time:  0.002544551060117524 (+/-) 0.0004975194095362649
# Training Time:  2.728229489819757 (+/-) 0.1884812506503208
#
#
# === Average network evolution ===
# Total hidden node:  27.833333333333332 (+/-) 0.9339283817414601
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=24, out_features=29, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 24
# No. of nodes : 29
# No. of parameters : 749
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=29, out_features=2, bias=True)
# )
# No. of inputs : 29
# No. of output : 2
# No. of parameters : 60
# 100% (30 of 30) |########################| Elapsed Time: 0:01:15 ETA:  00:00:00
# === Performance result ===
# Accuracy:  78.7448275862069 (+/-) 6.079336749605263
# Precision:  0.7567491794628006
# Recall:  0.787448275862069
# F1 score:  0.7592427523748112
# Testing Time:  0.002543531615158607 (+/-) 0.0004964956119006578
# Training Time:  2.605247028942766 (+/-) 0.10051130829555298
#
#
# === Average network evolution ===
# Total hidden node:  19.433333333333334 (+/-) 0.7608474807008885
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=24, out_features=20, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 24
# No. of nodes : 20
# No. of parameters : 524
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=20, out_features=2, bias=True)
# )
# No. of inputs : 20
# No. of output : 2
# No. of parameters : 42
# ========== Performance occupancy ==========
# Preq Accuracy:  79.11 (+/-) 0.96
# F1 score:  0.76 (+/-) 0.0
# Precision:  0.76 (+/-) 0.01
# Recall:  0.79 (+/-) 0.01
# Training time:  2.83 (+/-) 0.39
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  26.0 (+/-) 3.52

# %%
# %run DEVDAN_hyperplane.ipynb
# Out:
# Number of input:  4
# Number of output:  2
# Number of batch:  120
# All Data
# 100% (120 of 120) |######################| Elapsed Time: 0:05:02 ETA:  00:00:00
# === Performance result ===
# Accuracy:  92.16806722689077 (+/-) 2.3297106529723783
# Precision:  0.921770569622901
# Recall:  0.9216806722689076
# F1 score:  0.9216774759021741
# Testing Time:  0.0016296631147881516 (+/-) 0.0005878502918390763
# Training Time:  2.5384743033336994 (+/-) 0.08014173607181502
#
#
# === Average network evolution ===
# Total hidden node:  7.366666666666666 (+/-) 0.5467073155618908
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=4, out_features=7, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 4
# No. of nodes : 7
# No. of parameters : 39
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=7, out_features=2, bias=True)
# )
# No. of inputs : 7
# No. of output : 2
# No. of parameters : 16
# 100% (120 of 120) |######################| Elapsed Time: 0:05:00 ETA:  00:00:00
# === Performance result ===
# Accuracy:  92.10336134453783 (+/-) 2.0953302530699367
# Precision:  0.9210770236218623
# Recall:  0.9210336134453782
# F1 score:  0.9210308752715786
# Testing Time:  0.0015899373703644056 (+/-) 0.0005238990488585577
# Training Time:  2.521980520056075 (+/-) 0.08440537249031918
#
#
# === Average network evolution ===
# Total hidden node:  9.016666666666667 (+/-) 0.3411581581743119
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=4, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 4
# No. of nodes : 9
# No. of parameters : 49
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of output : 2
# No. of parameters : 20
# 100% (120 of 120) |######################| Elapsed Time: 0:05:07 ETA:  00:00:00
# === Performance result ===
# Accuracy:  92.15378151260504 (+/-) 2.2062855173789346
# Precision:  0.9216186142068811
# Recall:  0.9215378151260504
# F1 score:  0.9215349837100562
# Testing Time:  0.0015271331081871224 (+/-) 0.0006026627969402369
# Training Time:  2.5772294597465453 (+/-) 0.12863808472733235
#
#
# === Average network evolution ===
# Total hidden node:  12.741666666666667 (+/-) 0.831623245359473
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=4, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 4
# No. of nodes : 13
# No. of parameters : 69
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of output : 2
# No. of parameters : 28
# 100% (120 of 120) |######################| Elapsed Time: 0:05:09 ETA:  00:00:00
# === Performance result ===
# Accuracy:  91.58319327731094 (+/-) 2.4813021563717927
# Precision:  0.916003245755705
# Recall:  0.9158319327731093
# F1 score:  0.9158247405540029
# Testing Time:  0.0016436677019135292 (+/-) 0.0005703666660646814
# Training Time:  2.595925669710175 (+/-) 0.17693180542245202
#
#
# === Average network evolution ===
# Total hidden node:  12.708333333333334 (+/-) 1.7097555055881202
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=4, out_features=13, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 4
# No. of nodes : 13
# No. of parameters : 69
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=13, out_features=2, bias=True)
# )
# No. of inputs : 13
# No. of output : 2
# No. of parameters : 28
# 100% (120 of 120) |######################| Elapsed Time: 0:05:05 ETA:  00:00:00
# === Performance result ===
# Accuracy:  92.0176470588235 (+/-) 2.090540803290489
# Precision:  0.9202238600551933
# Recall:  0.9201764705882353
# F1 score:  0.9201749429514402
# Testing Time:  0.0016814941117743484 (+/-) 0.0005744675455118871
# Training Time:  2.5629659099739137 (+/-) 0.09155181745560441
#
#
# === Average network evolution ===
# Total hidden node:  9.016666666666667 (+/-) 0.5913731666403392
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=4, out_features=9, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 4
# No. of nodes : 9
# No. of parameters : 49
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=9, out_features=2, bias=True)
# )
# No. of inputs : 9
# No. of output : 2
# No. of parameters : 20
# ========== Performance occupancy ==========
# Preq Accuracy:  92.01 (+/-) 0.22
# F1 score:  0.92 (+/-) 0.0
# Precision:  0.92 (+/-) 0.0
# Recall:  0.92 (+/-) 0.0
# Training time:  2.56 (+/-) 0.03
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  10.2 (+/-) 2.4

# %%
# %run DEVDAN_hepmass.ipynb
# Out:
# Number of input:  28
# Number of output:  2
# Number of batch:  2000
# All Data
# 100% (2000 of 2000) |####################| Elapsed Time: 1:09:45 ETA:  00:00:00
# === Performance result ===
# Accuracy:  84.10115057528765 (+/-) 1.5387291901431903
# Precision:  0.841686898967673
# Recall:  0.8410115057528764
# F1 score:  0.8409321682625703
# Testing Time:  0.0023576154179308284 (+/-) 0.0005126808909762762
# Training Time:  2.079342392696745 (+/-) 0.14357727989926095
#
#
# === Average network evolution ===
# Total hidden node:  13.0985 (+/-) 0.3738953730657816
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=28, out_features=14, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 28
# No. of nodes : 14
# No. of parameters : 434
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=14, out_features=2, bias=True)
# )
# No. of inputs : 14
# No. of output : 2
# No. of parameters : 30
# 100% (2000 of 2000) |####################| Elapsed Time: 1:26:39 ETA:  00:00:00
# === Performance result ===
# Accuracy:  84.05962981490745 (+/-) 1.5985943246924732
# Precision:  0.8412903519283637
# Recall:  0.8405962981490746
# F1 score:  0.8405144697195794
# Testing Time:  0.002724078609205115 (+/-) 0.001044524213106465
# Training Time:  2.58385470284409 (+/-) 0.3536107714008805
#
#
# === Average network evolution ===
# Total hidden node:  13.981 (+/-) 0.2015911704415647
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=28, out_features=14, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 28
# No. of nodes : 14
# No. of parameters : 434
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=14, out_features=2, bias=True)
# )
# No. of inputs : 14
# No. of output : 2
# No. of parameters : 30
# 100% (2000 of 2000) |####################| Elapsed Time: 1:19:01 ETA:  00:00:00
# === Performance result ===
# Accuracy:  83.98969484742372 (+/-) 1.649931815083786
# Precision:  0.8420986508475916
# Recall:  0.8398969484742371
# F1 score:  0.8396376009784847
# Testing Time:  0.0026762701380902854 (+/-) 0.0015140253920237115
# Training Time:  2.3554016568172926 (+/-) 0.30816770133470395
#
#
# === Average network evolution ===
# Total hidden node:  19.9685 (+/-) 0.6344349848487236
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=28, out_features=20, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 28
# No. of nodes : 20
# No. of parameters : 608
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=20, out_features=2, bias=True)
# )
# No. of inputs : 20
# No. of output : 2
# No. of parameters : 42
# 100% (2000 of 2000) |####################| Elapsed Time: 1:34:18 ETA:  00:00:00
# === Performance result ===
# Accuracy:  84.20150075037517 (+/-) 1.5712008416866687
# Precision:  0.8427814970115021
# Recall:  0.8420150075037519
# F1 score:  0.8419258680474495
# Testing Time:  0.003035184679894879 (+/-) 0.0014146302082443105
# Training Time:  2.8123924555690243 (+/-) 0.15491257185373478
#
#
# === Average network evolution ===
# Total hidden node:  19.4805 (+/-) 0.5971764814525099
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=28, out_features=20, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 28
# No. of nodes : 20
# No. of parameters : 608
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=20, out_features=2, bias=True)
# )
# No. of inputs : 20
# No. of output : 2
# No. of parameters : 42
# 100% (2000 of 2000) |####################| Elapsed Time: 1:20:18 ETA:  00:00:00
# === Performance result ===
# Accuracy:  84.15547773886942 (+/-) 1.4707720233101953
# Precision:  0.843262003980895
# Recall:  0.8415547773886943
# F1 score:  0.8413563679620559
# Testing Time:  0.0027933424863295295 (+/-) 0.0006562010219182169
# Training Time:  2.3941193742117566 (+/-) 0.19638014780078197
#
#
# === Average network evolution ===
# Total hidden node:  13.2265 (+/-) 0.5737575707561513
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=28, out_features=14, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 28
# No. of nodes : 14
# No. of parameters : 434
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=14, out_features=2, bias=True)
# )
# No. of inputs : 14
# No. of output : 2
# No. of parameters : 30
# ========== Performance occupancy ==========
# Preq Accuracy:  84.1 (+/-) 0.07
# F1 score:  0.84 (+/-) 0.0
# Precision:  0.84 (+/-) 0.0
# Recall:  0.84 (+/-) 0.0
# Training time:  2.45 (+/-) 0.24
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  16.4 (+/-) 2.94

# %%
# %run DEVDAN_susy.ipynb
# Out:
# Number of input:  18
# Number of output:  2
# Number of batch:  2000
# All Data
# 100% (2000 of 2000) |####################| Elapsed Time: 1:24:26 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.60745372686344 (+/-) 2.5099680156238238
# Precision:  0.7783156581412767
# Recall:  0.7760745372686343
# F1 score:  0.7738723808146143
# Testing Time:  0.0024137761725253498 (+/-) 0.0009052274953912382
# Training Time:  2.5179939520484274 (+/-) 0.06571351850144012
#
#
# === Average network evolution ===
# Total hidden node:  19.786 (+/-) 2.3929488084787773
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=18, out_features=21, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 18
# No. of nodes : 21
# No. of parameters : 417
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=21, out_features=2, bias=True)
# )
# No. of inputs : 21
# No. of output : 2
# No. of parameters : 44
# 100% (2000 of 2000) |####################| Elapsed Time: 1:25:09 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.31060530265133 (+/-) 2.9609696476693417
# Precision:  0.7747458939329729
# Recall:  0.7731060530265133
# F1 score:  0.7711202902939972
# Testing Time:  0.0023153025010277353 (+/-) 0.0006297235709818389
# Training Time:  2.5393769950971654 (+/-) 0.07116393040469672
#
#
# === Average network evolution ===
# Total hidden node:  17.19 (+/-) 3.2882974318026643
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=18, out_features=19, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 18
# No. of nodes : 19
# No. of parameters : 379
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=19, out_features=2, bias=True)
# )
# No. of inputs : 19
# No. of output : 2
# No. of parameters : 40
# 100% (2000 of 2000) |####################| Elapsed Time: 1:25:05 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.51095547773886 (+/-) 2.4197836088947495
# Precision:  0.7775189725632266
# Recall:  0.7751095547773887
# F1 score:  0.7728105570124109
# Testing Time:  0.0024061459431116315 (+/-) 0.0006368250038869782
# Training Time:  2.5377742412866744 (+/-) 0.05033838219653272
#
#
# === Average network evolution ===
# Total hidden node:  22.0295 (+/-) 1.7809070020638362
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=18, out_features=22, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 18
# No. of nodes : 22
# No. of parameters : 436
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=22, out_features=2, bias=True)
# )
# No. of inputs : 22
# No. of output : 2
# No. of parameters : 46
# 100% (2000 of 2000) |####################| Elapsed Time: 1:24:23 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.45222611305653 (+/-) 2.3737968010182993
# Precision:  0.7773998040399186
# Recall:  0.7745222611305653
# F1 score:  0.7720070087530162
# Testing Time:  0.0024229617879771184 (+/-) 0.0008566320234193204
# Training Time:  2.5164168050373834 (+/-) 0.041061104495336495
#
#
# === Average network evolution ===
# Total hidden node:  19.9625 (+/-) 1.9191388042557007
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=18, out_features=22, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 18
# No. of nodes : 22
# No. of parameters : 436
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=22, out_features=2, bias=True)
# )
# No. of inputs : 22
# No. of output : 2
# No. of parameters : 46
# 100% (2000 of 2000) |####################| Elapsed Time: 1:24:28 ETA:  00:00:00
# === Performance result ===
# Accuracy:  77.56833416708355 (+/-) 2.4985363952617177
# Precision:  0.7780707613392933
# Recall:  0.7756833416708354
# F1 score:  0.7734074523940311
# Testing Time:  0.0024142994052949937 (+/-) 0.0015832128988225425
# Training Time:  2.5192194828216645 (+/-) 0.05172858149406109
#
#
# === Average network evolution ===
# Total hidden node:  22.908 (+/-) 2.2278994591318524
#
#
# === Final network structure ===
#
#  1 -th layer
# hiddenLayerBasicNet(
#   (linear): Linear(in_features=18, out_features=24, bias=True)
#   (activation): Sigmoid()
#   (activationh): ReLU(inplace=True)
# )
# No. of inputs : 18
# No. of nodes : 24
# No. of parameters : 474
#
#  2 -th layer
# outputLayerBasicNet(
#   (linearOutput): Linear(in_features=24, out_features=2, bias=True)
# )
# No. of inputs : 24
# No. of output : 2
# No. of parameters : 50
# ========== Performance occupancy ==========
# Preq Accuracy:  77.49 (+/-) 0.1
# F1 score:  0.77 (+/-) 0.0
# Precision:  0.78 (+/-) 0.0
# Recall:  0.77 (+/-) 0.0
# Training time:  2.53 (+/-) 0.01
# Testing time:  0.0 (+/-) 0.0
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  21.6 (+/-) 1.62
