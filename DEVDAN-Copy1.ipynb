# %% [markdown]
# ### License

# %%
# NANYANG TECHNOLOGICAL UNIVERSITY - NTUITIVE PTE LTD Dual License Agreement
# Non-Commercial Use Only

# This NTUITIVE License Agreement, including all exhibits ("NTUITIVE-LA") is a legal agreement between you 
# and NTUITIVE (or “we”) located at 71 Nanyang Drive, NTU Innovation Centre, #01-109, Singapore 637722, 
# a wholly owned subsidiary of Nanyang Technological University (“NTU”) for the software or data identified above, 
# which may include source code, and any associated materials, text or speech files, associated media and "online" or 
# electronic documentation and any updates we provide in our discretion (together, the "Software").

# By installing, copying, or otherwise using this Software, found at https://github.com/andriash001 or 
# https://www.researchgate.net/publication/335757711_ADL_Code_mFile or https://github.com/ContinualAL/ADL, 
# you agree to be bound by the terms of this NTUITIVE-LA. If you do not agree, do not install copy or 
# use the Software. The Software is protected by copyright and other intellectual property laws and 
# is licensed, not sold. If you wish to obtain a commercial royalty bearing license to this software 
# please contact us at mpratama@ntu.edu.sg or andriash001@e.ntu.edu.sg.

# SCOPE OF RIGHTS:
# You may use, copy, reproduce, and distribute this Software for any non-commercial purpose, subject to the 
# restrictions in this NTUITIVE-LA. Some purposes which can be non-commercial are teaching, academic research, 
# public demonstrations and personal experimentation. You may also distribute this Software with books or other 
# teaching materials, or publish the Software on websites, that are intended to teach the use of the Software for 
# academic or other non-commercial purposes.

# You may not use or distribute this Software or any derivative works in any form for commercial purposes. Examples 
# of commercial purposes would be running business operations, licensing, leasing, or selling the Software, distributing 
# the Software for use with commercial products, using the Software in the creation or use of commercial products or 
# any other activity which purpose is to procure a commercial gain to you or others.

# If the Software includes source code or data, you may create derivative works of such portions of the Software and 
# distribute the modified Software for non-commercial purposes, as provided herein.

# If you distribute the Software or any derivative works of the Software, you will distribute them under the same terms 
# and conditions as in this license, and you will not grant other rights to the Software or derivative works that are 
# different from those provided by this NTUITIVE-LA.

# If you have created derivative works of the Software, and distribute such derivative works, you will cause 
# the modified files to carry prominent notices so that recipients know that they are not receiving the original Software. 
# Such notices must state: (i) that you have changed the Software; and (ii) the date of any changes.

# You may not distribute this Software or any derivative works. In return, we simply require that you agree:

# That you will not remove any copyright or other notices from the Software.
# That if any of the Software is in binary format, you will not attempt to modify such portions of the Software, or 
# to reverse engineer or decompile them, except and only to the extent authorized by applicable law.

# That NTUITIVE is granted back, without any restrictions or limitations, a non-exclusive, perpetual, irrevocable, 
# royalty-free, assignable and sub-licensable license, to reproduce, publicly perform or display, install, use, 
# modify, post, distribute, make and have made, sell and transfer your modifications to and/or derivative works of 
# the Software source code or data, for any purpose.

# That any feedback about the Software provided by you to us is voluntarily given, and NTUITIVE shall be free to use 
# the feedback as it sees fit without obligation or restriction of any kind, even if the feedback is designated by 
# you as confidential.

# THAT THE SOFTWARE COMES "AS IS", WITH NO WARRANTIES. THIS MEANS NO EXPRESS, IMPLIED OR STATUTORY WARRANTY, 
# INCLUDING WITHOUT LIMITATION, WARRANTIES OF MERCHANTABILITY OR FITNESS FOR A PARTICULAR PURPOSE, ANY WARRANTY AGAINST 
# INTERFERENCE WITH YOUR ENJOYMENT OF THE SOFTWARE OR ANY WARRANTY OF TITLE OR NON-INFRINGEMENT. THERE IS NO WARRANTY 
# THAT THIS SOFTWARE WILL FULFILL ANY OF YOUR PARTICULAR PURPOSES OR NEEDS. ALSO, YOU MUST PASS THIS DISCLAIMER ON 
# WHENEVER YOU DISTRIBUTE THE SOFTWARE OR DERIVATIVE WORKS.

# THAT NEITHER NTUITIVE NOR NTU NOR ANY CONTRIBUTOR TO THE SOFTWARE WILL BE LIABLE FOR ANY DAMAGES RELATED TO 
# THE SOFTWARE OR THIS NTUITIVE-LA, INCLUDING DIRECT, INDIRECT, SPECIAL, CONSEQUENTIAL OR INCIDENTAL DAMAGES, 
# TO THE MAXIMUM EXTENT THE LAW PERMITS, NO MATTER WHAT LEGAL THEORY IT IS BASED ON. ALSO, YOU MUST PASS 
# THIS LIMITATION OF LIABILITY ON WHENEVER YOU DISTRIBUTE THE SOFTWARE OR DERIVATIVE WORKS.
# That we have no duty of reasonable care or lack of negligence, and we are not obligated to (and will not) 
# provide technical support for the Software.

# That if you breach this NTUITIVE-LA or if you sue anyone over patents that you think may apply to or read on 
# the Software or anyone's use of the Software, this NTUITIVE-LA (and your license and rights obtained herein) 
# terminate automatically. Upon any such termination, you shall destroy all of your copies of the Software immediately. 
# Sections 3, 4, 5, 6, 7, 8, 11 and 12 of this NTUITIVE-LA shall survive any termination of this NTUITIVE-LA.
# That the patent rights, if any, granted to you in this NTUITIVE-LA only apply to the Software, not to any 
# derivative works you make.

# That the Software may be subject to U.S. export jurisdiction at the time it is licensed to you, and it may be 
# subject to additional export or import laws in other places. You agree to comply with all such laws and 
# regulations that may apply to the Software after delivery of the software to you.
# That all rights not expressly granted to you in this NTUITIVE-LA are reserved.

# That this NTUITIVE-LA shall be construed and controlled by the laws of the Republic of Singapore without 
# regard to conflicts of law. If any provision of this NTUITIVE-LA shall be deemed unenforceable or contrary to law, 
# the rest of this NTUITIVE-LA shall remain in full effect and interpreted in an enforceable manner that 
# most nearly captures the intent of the original language.

# Do you accept all of the terms of the preceding NTUITIVE-LA license agreement? 

# If you accept the terms, click “I Agree,” then “Next.” Otherwise click “Cancel.”

# Copyright (c) NTUITIVE. All rights reserved.

# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd
import time 
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
from numpy import linalg as LA
import scipy
from scipy import io
import pdb

# %% [markdown]
# ### Utils ADL

# %%
class meanStdCalculator(object):
    # developed and modified from https://github.com/pytorch/examples/blob/master/imagenet/main.py#L247-L262
    # license BSD 3-Clause "New" or "Revised" License
    def __init__(self):
        self.mean     = 0.0
        self.mean_old = 0.0
        self.std      = 0.001
        self.count    = 0
        self.minMean  = 100.0
        self.minStd   = 100.0
        self.M_old    = 0.0
        self.M        = 0.0
        self.S        = 0.0001
        self.S_old    = 0.0
        # warnings.filterwarnings("ignore", category=RuntimeWarning) 
        
    def updateMeanStd(self, data, cnt = 1):
        self.data     = data
        self.mean_old = self.mean  # copy.deepcopy(self.mean)
        self.M_old    = self.count*self.mean_old
        self.M        = self.M_old + data
        self.S_old    = self.S     # copy.deepcopy(self.S)
        if self.count > 0:
            self.S    = self.S_old + ((self.count*data - self.M_old)**2)/(self.count*(self.count + cnt) + 0.0001)
        
        self.count   += cnt
        self.mean     = self.mean_old + (data-self.mean_old)/((self.count + 0.0001))  # np.divide((data-self.mean_old),self.count + 0.0001)
        self.std      = np.sqrt(self.S/(self.count + 0.0001))
        
        # if (self.std != self.std).any():
        #     print('There is NaN in meanStd')
        #     pdb.set_trace()
    
    def resetMinMeanStd(self):
        self.minMean = self.mean  # copy.deepcopy(self.mean)
        self.minStd  = self.std   # copy.deepcopy(self.std)
        
    def updateMeanStdMin(self):
        if self.mean < self.minMean:
            self.minMean = self.mean  # copy.deepcopy(self.mean)
        if self.std < self.minStd:
            self.minStd  = self.std   # copy.deepcopy(self.std)

# %%
def probitFunc(meanIn,stdIn):
    stdIn += 0.0001  # for safety
    out = meanIn/(torch.ones(1) + (np.pi/8)*stdIn**2)**0.5
    
    return out

# %%
def generateWeightXavInit(nInput,nNode,nOut,nNewNode):
    copyNet         = devdan(nInput,nNode,nOut)
    newWeight       = copyNet.linear.weight.data[0:nNewNode]
    newWeightNext   = copyNet.linear.weight.data[:,0:nNewNode]
    newOutputWeight = copyNet.linearOutput.weight.data[:,0:nNewNode]
    
    return newWeight, newOutputWeight, newWeightNext

# %%
def deleteRowTensor(x,index):
    x = x[torch.arange(x.size(0))!=index] 
    
    return x

# %%
def deleteColTensor(x,index):
    x = x.transpose(1,0)
    x = x[torch.arange(x.size(0))!=index]
    x = x.transpose(1,0)
    
    return x

# %%
def oneHot(label,nClass):
    nData = label.shape[0]
    
    oneHot = torch.zeros(nData,nClass)
    
    for i, lbl in enumerate(label):
        oneHot[i][lbl] = 1
    
    return oneHot

# %%
def maskingNoise(x,noiseIntensity = 0.1):
    # noiseStr: the ammount of masking noise 0~1*100%
    
    nData, nInput = x.shape
    nMask = np.max([int(noiseIntensity*nInput),1])
    for i,_ in enumerate(x):
        maskIdx = np.random.randint(nInput,size = nMask)
        x[i][maskIdx] = 0
    
    return x

# %% [markdown]
# ### Network

# %%
class devdan(nn.Module):
    def __init__(self, no_input, no_hidden, classes):
        super(devdan, self).__init__()
        
        # encoder
        self.linear = nn.Linear(no_input, no_hidden,  bias=True)
        nn.init.xavier_uniform_(self.linear.weight)
        self.linear.bias.data.zero_()
        
        # decoder
        self.biasDecoder = nn.Parameter(torch.zeros(no_input))
        
        # softmax layer
        self.linearOutput = nn.Linear(no_hidden, classes,  bias=True)
        nn.init.xavier_uniform_(self.linearOutput.weight)
        self.linearOutput.bias.data.zero_()
        
        self.activation = nn.Sigmoid()
        
        
    def forward(self, x, x_2):
        if x is not None:
            x  = self.linear(x)
            h  = self.activation(x)
            
            with torch.no_grad():
                a  = x.clone().detach()
                h2 = (h.clone().detach())**2
                x2 = self.linearOutput(h2)
            
            # decoder
            r  = F.linear(h, self.linear.weight.t()) + self.biasDecoder
            r  = self.activation(r)  # reconstructed input

            # classifier
            x  = self.linearOutput(h)
            
        else:
            x  = torch.tensor([[0.0]])
            h  = torch.tensor([[0.0]])
            r  = torch.tensor([[0.0]])
            x2 = torch.tensor([[0.0]])
            a  = torch.tensor([[0.0]])
        
        if x_2 is not None:
            with torch.no_grad():
                r_2 = F.linear(x_2, self.linear.weight.t()) + self.biasDecoder
                r_2 = self.activation(r_2)  # reconstructed input
        else:
            r_2 = torch.tensor([[0.0]])
        
        return x, h.clone().detach(), x2.clone().detach(), r, a, r_2.clone().detach()
    
def createDevdan(no_input,no_hidden,classes):
    obj = devdan(no_input,no_hidden,classes)
    
    return obj

# %%
def devdanFeedforwardTest(netList,x,votingWeight,device):
    # feedforward to all layers
    with torch.no_grad():
        classes = netList[0].linearOutput.weight.shape[0]
        nData   = x.shape[0]
        y       = torch.zeros(nData,classes)
        yList   = []
        hList   = []

        minibatch_data = x.to(device)
        minibatch_data = minibatch_data.type(torch.float)
        tempVar = minibatch_data

        for netLen in range(len(netList)):
            currnet                  = netList[netLen]
            obj                      = currnet.eval()
            obj                      = obj.to(device)
            tempY, tempVar,_,_,_,_   = obj(tempVar,None)
            hList                    = hList + [tempVar.tolist()]
            y                        = y + tempY*votingWeight[netLen]
            if votingWeight[netLen] == 0:
                yList        = yList + [[]]
            else:
                yList        = yList + [F.softmax(tempY,dim=1).tolist()]

    return y, yList, hList

# %%
def devdanFeedforwardBiasVarDisc(netList,netWinIdx,x,y,device):
    # feedforward from the input to the winning layer
    # y in one hot vector form, float, already put in device
    with torch.no_grad():
        minibatch_data  = x.to(device)
        minibatch_data  = minibatch_data.type(torch.float)
        minibatch_label = y
        
        tempVar = minibatch_data
        for netLen in range(len(netList)):
            currnet                       = netList[netLen]
            obj                           = currnet.eval()
            obj                           = obj.to(device)
            tempY, tempVar,tempY2,_,_,_   = obj(tempVar,None)
            
            if netLen == 0:
                tempVar2                  = (tempVar.clone().detach())**2
            else:
                tempY2,tempVar2,_,_,_,_,_ = obj(tempVar2,None)
                
            if netLen == netWinIdx:
                break
        
        tempY    = F.softmax(tempY,dim=1)
        tempY2   = F.softmax(tempY2,dim=1)
        bias     = torch.norm((tempY - minibatch_label)**2)
        variance = torch.norm(tempY2 - tempY**2)

    return bias.tolist(), variance.tolist(), tempVar

# %%
def devdanFeedforwardBiasVarGen(netList,netWinIdx,x,avgFeature,device):
    # feedforward from the input to the winning layer
    with torch.no_grad():
        minibatch_data = x.to(device)
        minibatch_data = minibatch_data.type(torch.float)
        tempVar = minibatch_data
        
        for netLen in range(len(netList)):
            currnet = netList[netLen]
            obj     = currnet.eval()
            obj     = obj.to(device)
            
            if netLen == 0:
                _, _,_,_,A,_       = obj(tempVar,None)
                avgFeature.updateMeanStd(A)
                
                tempVar            = probitFunc(avgFeature.mean,avgFeature.std)
                tempVar2           = (tempVar.clone().detach())**2
                _,_,_,_,_,tempVar  = obj(None,tempVar)
                _,_,_,_,_,tempVar2 = obj(None,tempVar2)
                
            else:
                _,_,_,tempVar,_,_  = obj(tempVar,None)
                _,_,_,tempVar2,_,_ = obj(tempVar2,None)
                
            if netLen == netWinIdx:
                break
        
        bias     = torch.mean((tempVar - minibatch_data)**2)
        variance = torch.mean(tempVar2 - minibatch_data**2)

    return bias.tolist(), variance.tolist(), tempVar, avgFeature

# %%
def devdanFeedforwardTrain(netWin,xWin,device):
    # feed forward only on winning layer
    minibatch_data = xWin.to(device)
    minibatch_data = minibatch_data.type(torch.float)
    minibatch_data.requires_grad_()
    
    netWin      = netWin.train()
    netWin      = netWin.to(device)
    y,_,_,r,_,_ = netWin(minibatch_data,None)
    
    return y, r

# %% [markdown]
# ### Train and Test

# %%
def devdanGenTrain(netList,netWinIdx,xWin,x,miuFeature,miuBias,miuVar,lr,criterion,device,epoch=1):
    
    print('GENERATIVE Training')
    
    # flags
    growNode  = False
    pruneNode = False
    
    # shuffle the data
    nData = x.shape[0]
    shuffled_indices = torch.randperm(nData)
    
    # masked input
    maskedX = maskingNoise(xWin.clone().detach())   # some of the input feature
#     maskedX = xWin.clone().detach()                   # without masking noise
    
    for iData in range(0,nData):
        # load data
        indices         = shuffled_indices[iData:iData+1]
        
        minibatch_xWin  = maskedX[indices]
        minibatch_xWin  = minibatch_xWin.to(device)
         
        minibatch_label = xWin[indices]
        minibatch_label = minibatch_label.to(device)
         
        minibatch_x     = x[indices]
        minibatch_x     = minibatch_x.to(device)
                
        # get bias and variance generative
        bias, variance, nodeSignificance, miuFeature = devdanFeedforwardBiasVarGen(
            netList,netWinIdx,minibatch_x,miuFeature,device)
        
        # calculate mean of bias
        miuBias[netWinIdx].updateMeanStd(bias)
        if miuBias[netWinIdx].count < 1 or growNode:
            miuBias[netWinIdx].resetMinMeanStd()
        else:
            miuBias[netWinIdx].updateMeanStdMin()
        
        # calculate mean of variance
        miuVar[netWinIdx].updateMeanStd(variance)
        if miuVar[netWinIdx].count < 20 or pruneNode:
            miuVar[netWinIdx].resetMinMeanStd()
        else:
            miuVar[netWinIdx].updateMeanStdMin()
        
        # growing
        growNode = growNodeIdentification(bias,miuBias[netWinIdx].minMean,miuBias[netWinIdx].minStd,
                                          miuBias[netWinIdx].mean,miuBias[netWinIdx].std)
        if growNode and miuBias[netWinIdx].count >= 1:
            # grow a node
            netList    = nodeGrowing(netList,netWinIdx,1)
            if netWinIdx == 0:
                miuFeature = meanStdCalculator()
        
        # pruning
        pruneNode = pruneNodeIdentification(variance,miuVar[netWinIdx].minMean,miuVar[netWinIdx].minStd,
                                            miuVar[netWinIdx].mean,miuVar[netWinIdx].std)
        if (pruneNode and not growNode and miuVar[netWinIdx].count >= 20 and 
           netList[netWinIdx].linear.weight.data.shape[0] > netList[netWinIdx].linearOutput.weight.data.shape[0]):
            pruneIdx   = findLeastSignificantNode(nodeSignificance)
            
            # prune a node
            netList    = nodePruning(netList,netWinIdx,pruneIdx)
            if netWinIdx == 0:
                miuFeature = meanStdCalculator()
            
        # active learning
        # if not growNode and not pruneNode and activeLearn:
            # active learning can be executed if there is no growing and pruning and active learning is triggered
        
        # declare parameters to be trained
        netOptim  = []
        netOptim  = netOptim + list(netList[netWinIdx].parameters())
        optimizer = torch.optim.SGD(netOptim, lr = lr) #, weight_decay = 5e-4)
        # optimizer = torch.optim.Adam(netOptim, lr = 0.05, weight_decay = 5e-4)
        
        # feedforward
        _,scores  = devdanFeedforwardTrain(netList[netWinIdx],minibatch_xWin,device)
        
        # calculate loss
        loss      = 0.5*criterion(scores,minibatch_label)
        
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print('Bias: ',miuBias[netWinIdx].mean)
    print('Variance: ',miuVar[netWinIdx].mean)
    
    return netList, miuFeature, miuBias, miuVar

# %%
def devdanDiscTrain(netList,netWinIdx,xWin,x,y,nClass,miuX,miuFeature,miuBias,miuVar,lr,criterion,device,epoch=1):
    
    print('DISCRIMINATIVE Training')
    
    # flags
    growNode  = False
    pruneNode = False
    
    # shuffle the data
    nData = x.shape[0]
    shuffled_indices = torch.randperm(nData)
    
    # label for bias var calculation
    y_biasVar = F.one_hot(y).float()
    if y_biasVar.shape[1] != nClass:
        y_biasVar = oneHot(y,nClass)
    
    for iData in range(0,nData):
        # load data
        
        indices                 = shuffled_indices[iData:iData+1]
               
        minibatch_xWin          = xWin[indices]
        minibatch_xWin          = minibatch_xWin.to(device)
               
        minibatch_label         = y[indices]
        minibatch_label         = minibatch_label.to(device)
        minibatch_label_biasVar = y_biasVar[indices]
        minibatch_label_biasVar = minibatch_label_biasVar.to(device)
        
        minibatch_x             = x[indices]
        minibatch_x             = minibatch_x.to(device)
        
        # calculate mean of input
        miuX.updateMeanStd(minibatch_x)
        
        # get bias and variance discriminative
        outProbit = probitFunc(miuX.mean,miuX.std)
        bias, variance, nodeSignificance = devdanFeedforwardBiasVarDisc(netList,netWinIdx,
                                                                 outProbit,minibatch_label_biasVar,device)
        
        # calculate mean of bias
        miuBias[netWinIdx].updateMeanStd(bias)
        if miuBias[netWinIdx].count < 1 or growNode:
            miuBias[netWinIdx].resetMinMeanStd()
        else:
            miuBias[netWinIdx].updateMeanStdMin()
        
        # calculate mean of variance
        miuVar[netWinIdx].updateMeanStd(variance)
        if miuVar[netWinIdx].count < 20 or pruneNode:
            miuVar[netWinIdx].resetMinMeanStd()
        else:
            miuVar[netWinIdx].updateMeanStdMin()
        
        # growing
        growNode = growNodeIdentification(bias,miuBias[netWinIdx].minMean,miuBias[netWinIdx].minStd,
                                          miuBias[netWinIdx].mean,miuBias[netWinIdx].std)
        if growNode and miuBias[netWinIdx].count >= 1:
            # grow a node
            netList = nodeGrowing(netList,netWinIdx,1)
            if netWinIdx == 0:
                miuFeature = meanStdCalculator()
        
        # pruning
        pruneNode = pruneNodeIdentification(variance,miuVar[netWinIdx].minMean,miuVar[netWinIdx].minStd,
                                            miuVar[netWinIdx].mean,miuVar[netWinIdx].std)
        if (pruneNode and not growNode and miuVar[netWinIdx].count >= 20 and 
           netList[netWinIdx].linear.weight.data.shape[0] > netList[netWinIdx].linearOutput.weight.data.shape[0]):
            pruneIdx = findLeastSignificantNode(nodeSignificance)
            
            # prune a node
            netList  = nodePruning(netList,netWinIdx,pruneIdx)
            if netWinIdx == 0:
                miuFeature = meanStdCalculator()
            
        # active learning
        # if not growNode and not pruneNode and activeLearn:
            # active learning can be executed if there is no growing and pruning and active learning is triggered
        
        # declare parameters to be trained
        netOptim  = []
        netOptim  = netOptim + list(netList[netWinIdx].parameters())
        optimizer = torch.optim.SGD(netOptim, lr = lr, momentum = 0.95) #, weight_decay = 5e-4)
        # optimizer = torch.optim.Adam(netOptim, lr = 0.05, weight_decay = 5e-4)
        
        # feedforward
        scores,_  = devdanFeedforwardTrain(netList[netWinIdx],minibatch_xWin,device)
        
        # calculate loss
        minibatch_label = minibatch_label.long()
        loss            = criterion(scores,minibatch_label)
        
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print('Bias: ',miuBias[netWinIdx].mean)
    print('Variance: ',miuVar[netWinIdx].mean)
    
    return netList, miuX, miuBias, miuVar, miuFeature

# %%
def devdanTest(netList,votingWeight,test_data,test_label,batch_size,criterion,device):
    # load data
    test_data  = test_data.to(device)
    test_label = test_label.to(device)
    test_label = test_label.long()
    
    # testing
    start_test              = time.time()
    scores,scoresList,_     = devdanFeedforwardTest(netList,test_data,votingWeight,device)
    rawPredicted, predicted = torch.max(F.softmax(scores.data,dim=1), 1)
    end_test                = time.time()

    # performance calculation
    loss          = criterion(scores,test_label)
    residualError = torch.tensor([1.0]) - rawPredicted
    correct       = (predicted == test_label).sum().item()
    accuracy      = 100*correct/(predicted == test_label).shape[0]  # 1: correct, 0: wrong
    testing_time  = end_test - start_test
    F_matrix      = (predicted != test_label).int().tolist()  # 1: wrong, 0: correct
    lossList      = []
    F_matrixList  = []
    for netLen in range(len(netList)):
        if votingWeight[netLen] == 0:
            F_matrixList = F_matrixList + [[]]
            lossList     = lossList + [-1]  # -1 loss value indicate that the layer is already pruned
        else:
            _, predicted = torch.max(torch.FloatTensor(scoresList[netLen]).data, 1)
            F_matrixList = F_matrixList + [(predicted != test_label).int().tolist()]  # 1: wrong, 0: correct
            loacalLoss   = criterion(torch.FloatTensor(scoresList[netLen]),test_label)
            lossList     = lossList + [loacalLoss.tolist()]
        
    print('Testing Accuracy: {}'.format(accuracy))
    print('Testing Loss: {}'.format(loss))
    print('Testing Time: {}'.format(testing_time))
    
    return scores, scoresList, loss, lossList, residualError, accuracy, testing_time, F_matrix, F_matrixList

# %% [markdown]
# ### Network Evaluation

# %%
def growNodeIdentification(bias,minMeanBias,minStdBias,meanBias,stdBias):
    growNode = False
    
    dynamicKsigmaGrow = 1.3*np.exp(-bias) + 0.7
    growCondition1    = minMeanBias + dynamicKsigmaGrow*minStdBias
    growCondition2    = meanBias + stdBias
    
    if growCondition2 > growCondition1:
        growNode = True
    
    return growNode

# %%
def pruneNodeIdentification(var,minMeanVar,minStdVar,meanVar,stdVar):
    pruneNode = False
    
    dynamicKsigmaPrune = 1.3*np.exp(-var) + 0.7
    pruneCondition1    = minMeanVar + 2*dynamicKsigmaPrune*minStdVar
    pruneCondition2    = meanVar + stdVar
    
    if pruneCondition2 > pruneCondition1:
        pruneNode = True
    
    return pruneNode

# %%
def findLeastSignificantNode(nodeSig):
    leastSigIdx = torch.argmin(torch.abs(nodeSig)).tolist()
    
    return leastSigIdx

# %% [markdown]
# ### Evolving

# %%
def nodeGrowing(netList,winIdx,nNewNode):
    if winIdx <= (len(netList)-1):
        netList      = copy.deepcopy(netList)
        
        nInputWin    = netList[winIdx].linear.weight.shape[1]
        nNodeWin     = netList[winIdx].linear.weight.shape[0]
        nOutput      = netList[winIdx].linearOutput.weight.shape[0]
        nNewNodeCurr = nNodeWin + nNewNode

        # grow node for current layer, output
        newWeight, newOutputWeight,_         = generateWeightXavInit(nInputWin,nNewNodeCurr,nOutput,nNewNode)
        netList[winIdx].linear.weight.data   = torch.cat((netList[winIdx].linear.weight.data,
                                                          newWeight),0)  # grow input weights
        netList[winIdx].linear.bias.data     = torch.cat((netList[winIdx].linear.bias.data,
                                                          torch.zeros(nNewNode)),0)  # grow input bias
        netList[winIdx].linear.out_features  = nNewNodeCurr
        del netList[winIdx].linear.weight.grad
        del netList[winIdx].linear.bias.grad
        
        # grow input weight of linearOutput
        netList[winIdx].linearOutput.weight.data = torch.cat((netList[winIdx].linearOutput.weight.data,
                                                                newOutputWeight),1)
        netList[winIdx].linearOutput.in_features = nNewNodeCurr
        del netList[winIdx].linearOutput.weight.grad
        del netList[winIdx].linearOutput.bias.grad

        if winIdx != (len(netList)-1):
            nextIdx       = winIdx + 1
            nInputNext    = netList[nextIdx].linear.weight.shape[1]
            nNodeNext     = netList[nextIdx].linear.weight.shape[0]
            nOutputNext   = netList[nextIdx].linearOutput.weight.shape[0]
            nNewInputNext = nInputNext + nNewNode

            # grow input weight of next layer
            _,_,newWeightNext = generateWeightXavInit(nNewInputNext,nNodeNext,nOutputNext,nNewNode)
            netList[nextIdx].linear.weight.data = torch.cat((netList[nextIdx].linear.weight.data,newWeightNext),1)
            netList[nextIdx].biasDecoder.data   = torch.cat((netList[nextIdx].biasDecoder.data,
                                                             torch.zeros(nNewNode)),0)
            del netList[nextIdx].linear.weight.grad
            del netList[nextIdx].biasDecoder.grad

            # update input features
            netList[nextIdx].linear.in_features = nNewInputNext
            
        print('+++ GROW a hidden NODE +++')
    else:
        raise IndexError
    
    return copy.deepcopy(netList)

# %%
def nodePruning(netList,winIdx,pruneIdx):
    if winIdx <= (len(netList)-1):
        netList      = copy.deepcopy(netList)
        
        nNodeWin     = netList[winIdx].linear.weight.shape[0]
        nPrunedNode  = 1
        nNewNodeCurr = nNodeWin - nPrunedNode  # prune a node

        # prune node for current layer, output
        netList[winIdx].linear.weight.data  = deleteRowTensor(netList[winIdx].linear.weight.data,
                                                           pruneIdx)  # prune input weights
        netList[winIdx].linear.bias.data    = deleteRowTensor(netList[winIdx].linear.bias.data,
                                                           pruneIdx)  # prune input bias
        netList[winIdx].linear.out_features = nNewNodeCurr
        del netList[winIdx].linear.weight.grad
        del netList[winIdx].linear.bias.grad

        # prune input weight of linearOutput
        netList[winIdx].linearOutput.weight.data = deleteColTensor(netList[winIdx].linearOutput.weight.data,pruneIdx)
        netList[winIdx].linearOutput.in_features = nNewNodeCurr
        del netList[winIdx].linearOutput.weight.grad
        del netList[winIdx].linearOutput.bias.grad

        if winIdx != (len(netList)-1):
            nextIdx       = winIdx + 1
            nInputNext    = netList[nextIdx].linear.weight.shape[1]
            nNewInputNext = nInputNext - nPrunedNode

            # prune input weight of next layer
            netList[nextIdx].linear.weight.data = deleteColTensor(netList[nextIdx].linear.weight.data,pruneIdx)
            netList[nextIdx].biasDecoder.data   = deleteRowTensor(netList[nextIdx].biasDecoder.data,pruneIdx)
            del netList[nextIdx].linear.weight.grad
            del netList[nextIdx].biasDecoder.grad

            # update input features
            netList[nextIdx].linear.in_features = nNewInputNext
        
        print('--- Hidden NODE No: ',pruneIdx,' is PRUNED ---')
        
    else:
        raise IndexError
    
    return copy.deepcopy(netList)

# %% [markdown]
# ### Main Loop

# %%
def DEVDANmainloop(net,votingWeight,averageInput,averageFeat,averageBias,
                   averageVar,averageBiasGen,averageVarGen,lr,lrGen,
                  preq_data,preq_label,nData,nBatch,batchSize,nInput,nOutput):
    # criterion
    criterion    = nn.CrossEntropyLoss()
    criterionGen = nn.MSELoss()

    # gpu setting
    device       = torch.device('cpu')
    
    # performance
    Accuracy     = meanStdCalculator()
    testingTime  = meanStdCalculator()
    trainingTime = meanStdCalculator()

    # flags
    netWinIdx   = 0

    # batch loop
    for iBatch in range(0,nBatch):
        print(iBatch,'- th batch of:', nBatch)

        # load data
        batchIdx   = iBatch + 1
        batchData  = preq_data[(batchIdx-1)*batchSize:batchIdx*batchSize]
        batchLabel = preq_label[(batchIdx-1)*batchSize:batchIdx*batchSize]
        nBatchData = batchData.shape[0]

        # testing
        scores, _, loss, _, _, accuracy, testing_time, _, _ = devdanTest(
            net,votingWeight,batchData,batchLabel,batchSize,criterion,device)

        # data augmentation
        # augment batchData and batchLabel

        start_train = time.time()
        # data preparation for training
        # get input for the winning layer
        if netWinIdx == 0:
            xWin = batchData
        else:
            _,_,hrList = devdanFeedforwardTest(net,batchData,votingWeight,device)
            xWin       = torch.FloatTensor(hrList[netWinIdx-1])

        # generative training
        net,averageFeat,averageBiasGen,averageVarGen = devdanGenTrain(
            net,netWinIdx,xWin,batchData,averageFeat,averageBiasGen,averageVarGen,lrGen,criterionGen,device)

        # discriminative training
        net,averageInput,averageBias,averageVar,averageFeat = devdanDiscTrain(net,netWinIdx,xWin,batchData,batchLabel,
            nOutput,averageInput,averageFeat,averageBias,averageVar,lr,criterion,device)

        end_train = time.time()
        training_time = end_train - start_train

        # calculate performance
        if iBatch > 0:
            Accuracy.updateMeanStd(accuracy)
            testingTime.updateMeanStd(testing_time)
            trainingTime.updateMeanStd(training_time)

        print('\n')
    
    print('=== FINAL result ===')
    print('Accuracy: ',Accuracy.mean,'(+/-)',Accuracy.std)
    print('Training Time: ',trainingTime.mean,'(+/-)',trainingTime.std)
    print('Testing Time: ',trainingTime.mean,'(+/-)',testingTime.std)
    print('Network structure: ')
        
    return net

# %% [markdown]
# ### Load data

# %%
# load data
data1      = scipy.io.loadmat(r'../sea2.mat')  # change your folder  electricitypricing2.mat
data       = data1.get('data')
data       = torch.from_numpy(data)
data       = data.float()
preq_data  = data[:,0:-1]
preq_label = data[:,-1]
preq_label = preq_label.long()
nData      = preq_data.shape[0]
batchSize  = 1000
nBatch     = int(nData/batchSize)
nInput     = preq_data.shape[1]
nOutput    = torch.unique(preq_label).shape[0]
print('Number of input: ', nInput)
print('Number of output: ', nOutput)
print('Number of batch: ', nBatch)
# Out:
# Number of input:  3
# Number of output:  2
# Number of batch:  100

# %% [markdown]
# ### Initialization

# %%
# initial network
net            = [createDevdan(nInput,nOutput,nOutput)]
votingWeight   = [1.0]

# network significance
averageInput   = meanStdCalculator()
averageFeat    = meanStdCalculator()
averageBias    = [meanStdCalculator()]
averageVar     = [meanStdCalculator()]
averageBiasGen = [meanStdCalculator()]
averageVarGen  = [meanStdCalculator()]

# parameters
lr             = 0.02  #0.01 learning rate
lrGen          = 0.001

# %%
net = DEVDANmainloop(net,votingWeight,averageInput,averageFeat,averageBias,
                   averageVar,averageBiasGen,averageVarGen,lr,lrGen,
                  preq_data,preq_label,nData,nBatch,batchSize,nInput,nOutput)
# Out:
# 0 - th batch of: 100
# Testing Accuracy: 63.2
# Testing Loss: 0.6677523255348206
# Testing Time: 0.0019936561584472656
# GENERATIVE Training
# +++ GROW a hidden NODE +++
# +++ GROW a hidden NODE +++
# +++ GROW a hidden NODE +++
# +++ GROW a hidden NODE +++
# Bias:  0.11889666628168669
# Variance:  0.16947645012485296
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# +++ GROW a hidden NODE +++
# --- Hidden NODE No:  1  is PRUNED ---
# Bias:  0.33406980624937205
# Variance:  0.3535642681013102
#
#
# 1 - th batch of: 100
# Testing Accuracy: 63.6
# Testing Loss: 0.6139960885047913
# Testing Time: 0.0020198822021484375
# GENERATIVE Training
# Bias:  0.11628773764390456
# Variance:  0.2080616278791668
# DISCRIMINATIVE Training
# Bias:  0.3320343402717655
# Variance:  0.3606605272415891
#
#
# 2 - th batch of: 100
# Testing Accuracy: 65.8
# Testing Loss: 0.5827054977416992
# Testing Time: 0.003987789154052734
# GENERATIVE Training
# Bias:  0.11542318446981722
# Variance:  0.22084469440597265
# DISCRIMINATIVE Training
# --- Hidden NODE No:  4  is PRUNED ---
# +++ GROW a hidden NODE +++
# Bias:  0.33110803056742527
# Variance:  0.3734287954566966
#
#
# 3 - th batch of: 100
# Testing Accuracy: 65.1
# Testing Loss: 0.5709105134010315
# Testing Time: 0.0030024051666259766
# GENERATIVE Training
# Bias:  0.11625486298366632
# Variance:  0.23241519188463605
# DISCRIMINATIVE Training
# --- Hidden NODE No:  6  is PRUNED ---
# Bias:  0.3333618012260534
# Variance:  0.39384003726759564
#
#
# 4 - th batch of: 100
# Testing Accuracy: 76.4
# Testing Loss: 0.5214613080024719
# Testing Time: 0.0019826889038085938
# GENERATIVE Training
# Bias:  0.117459538922218
# Variance:  0.23481271379073487
# DISCRIMINATIVE Training
# --- Hidden NODE No:  5  is PRUNED ---
# Bias:  0.3331036247680475
# Variance:  0.4251280412942574
#
#
# 5 - th batch of: 100
# Testing Accuracy: 83.3
# Testing Loss: 0.504240095615387
# Testing Time: 0.001978635787963867
# GENERATIVE Training
# Bias:  0.1168182420344012
# Variance:  0.23033280619659094
# DISCRIMINATIVE Training
# Bias:  0.3314384929202598
# Variance:  0.45528893073053933
#
#
# 6 - th batch of: 100
# Testing Accuracy: 79.6
# Testing Loss: 0.45063135027885437
# Testing Time: 0.0029609203338623047
# GENERATIVE Training
# Bias:  0.11938130139557736
# Variance:  0.2311960875424078
# DISCRIMINATIVE Training
# --- Hidden NODE No:  1  is PRUNED ---
# Bias:  0.3302958755677761
# Variance:  0.485981082202357
#
#
# 7 - th batch of: 100
# Testing Accuracy: 79.5
# Testing Loss: 0.44439640641212463
# Testing Time: 0.00200653076171875
# GENERATIVE Training
# Bias:  0.12311785225138393
# Variance:  0.23262267303839854
# DISCRIMINATIVE Training
# Bias:  0.3295383604527552
# Variance:  0.5169017423188867
#
#
# 8 - th batch of: 100
# Testing Accuracy: 88.3
# Testing Loss: 0.43402302265167236
# Testing Time: 0.0030062198638916016
# GENERATIVE Training
# Bias:  0.12590216507269938
# Variance:  0.23334875275797642
# DISCRIMINATIVE Training
# Bias:  0.32899062438877213
# Variance:  0.5438660792512614
#
#
# 9 - th batch of: 100
# Testing Accuracy: 81.3
# Testing Loss: 0.42525535821914673
# Testing Time: 0.001995086669921875
# GENERATIVE Training
# Bias:  0.1292803710535193
# Variance:  0.2354616955922589
# DISCRIMINATIVE Training
# Bias:  0.32853134519832283
# Variance:  0.5659540790855058
#
#
# 10 - th batch of: 100
# Testing Accuracy: 88.5
# Testing Loss: 0.4278216063976288
# Testing Time: 0.0029973983764648438
# GENERATIVE Training
# Bias:  0.13232501483253953
# Variance:  0.23714777507806936
# DISCRIMINATIVE Training
# --- Hidden NODE No:  2  is PRUNED ---
# Bias:  0.3294140397812696
# Variance:  0.5839034793911853
#
#
# 11 - th batch of: 100
# Testing Accuracy: 86.5
# Testing Loss: 0.40251249074935913
# Testing Time: 0.001993894577026367
# GENERATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.13911784301538277
# Variance:  0.24772992776388533
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.33009019454637234
# Variance:  0.5982594647347272
#
#
# 12 - th batch of: 100
# Testing Accuracy: 81.3
# Testing Loss: 0.46755263209342957
# Testing Time: 0.0019752979278564453
# GENERATIVE Training
# Bias:  0.1453933059244152
# Variance:  0.25883994543389816
# DISCRIMINATIVE Training
# Bias:  0.33158427052718636
# Variance:  0.6088782538128423
#
#
# 13 - th batch of: 100
# Testing Accuracy: 80.8
# Testing Loss: 0.43002164363861084
# Testing Time: 0.001984119415283203
# GENERATIVE Training
# Bias:  0.15142863629935516
# Variance:  0.2694017574746216
# DISCRIMINATIVE Training
# Bias:  0.33338945445568574
# Variance:  0.6178727744386922
#
#
# 14 - th batch of: 100
# Testing Accuracy: 89.1
# Testing Loss: 0.4010505974292755
# Testing Time: 0.0030176639556884766
# GENERATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.15519081106496993
# Variance:  0.27477713205628146
# DISCRIMINATIVE Training
# Bias:  0.33456747795741326
# Variance:  0.6275668537084936
#
#
# 15 - th batch of: 100
# Testing Accuracy: 88.7
# Testing Loss: 0.3651951849460602
# Testing Time: 0.001987934112548828
# GENERATIVE Training
# Bias:  0.15908652075717125
# Variance:  0.2801059535440433
# DISCRIMINATIVE Training
# Bias:  0.3359692468658078
# Variance:  0.6367514509715427
#
#
# 16 - th batch of: 100
# Testing Accuracy: 87.3
# Testing Loss: 0.3864938020706177
# Testing Time: 0.001993417739868164
# GENERATIVE Training
# Bias:  0.16225239390953683
# Variance:  0.2834596557767979
# DISCRIMINATIVE Training
# Bias:  0.337261936352248
# Variance:  0.6448602893829464
#
#
# 17 - th batch of: 100
# Testing Accuracy: 90.9
# Testing Loss: 0.37289345264434814
# Testing Time: 0.0029916763305664062
# GENERATIVE Training
# Bias:  0.16473273010479264
# Variance:  0.2861962011429158
# DISCRIMINATIVE Training
# Bias:  0.33783679885464185
# Variance:  0.651519879206785
#
#
# 18 - th batch of: 100
# Testing Accuracy: 87.9
# Testing Loss: 0.4296475648880005
# Testing Time: 0.002991199493408203
# GENERATIVE Training
# Bias:  0.16737610015010265
# Variance:  0.2893929316733722
# DISCRIMINATIVE Training
# Bias:  0.33872804264299555
# Variance:  0.6566153129053166
#
#
# 19 - th batch of: 100
# Testing Accuracy: 87.9
# Testing Loss: 0.40209537744522095
# Testing Time: 0.003988981246948242
# GENERATIVE Training
# Bias:  0.1703868426340216
# Variance:  0.2927963173770806
# DISCRIMINATIVE Training
# Bias:  0.34005064610127944
# Variance:  0.6604188375130302
#
#
# 20 - th batch of: 100
# Testing Accuracy: 83.2
# Testing Loss: 0.42195045948028564
# Testing Time: 0.0019922256469726562
# GENERATIVE Training
# Bias:  0.17327487315594536
# Variance:  0.2964516916174986
# DISCRIMINATIVE Training
# Bias:  0.34132389506514144
# Variance:  0.6638531685095123
#
#
# 21 - th batch of: 100
# Testing Accuracy: 85.4
# Testing Loss: 0.42903977632522583
# Testing Time: 0.0029816627502441406
# GENERATIVE Training
# Bias:  0.17555853567947016
# Variance:  0.2999235091866481
# DISCRIMINATIVE Training
# Bias:  0.3422063814813048
# Variance:  0.6668430461876024
#
#
# 22 - th batch of: 100
# Testing Accuracy: 87.2
# Testing Loss: 0.39193862676620483
# Testing Time: 0.0029914379119873047
# GENERATIVE Training
# Bias:  0.17781469444247427
# Variance:  0.3030567615291036
# DISCRIMINATIVE Training
# Bias:  0.34325126459172883
# Variance:  0.6697086868180264
#
#
# 23 - th batch of: 100
# Testing Accuracy: 87.2
# Testing Loss: 0.4092954397201538
# Testing Time: 0.0019631385803222656
# GENERATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.1799173216902237
# Variance:  0.30624630243174067
# DISCRIMINATIVE Training
# Bias:  0.34380175332587537
# Variance:  0.673973146199584
#
#
# 24 - th batch of: 100
# Testing Accuracy: 84.8
# Testing Loss: 0.4351480305194855
# Testing Time: 0.0029675960540771484
# GENERATIVE Training
# Bias:  0.18175049312957325
# Variance:  0.307164647933762
# DISCRIMINATIVE Training
# Bias:  0.3444726513843431
# Variance:  0.6770196591440426
#
#
# 25 - th batch of: 100
# Testing Accuracy: 78.6
# Testing Loss: 0.4622160792350769
# Testing Time: 0.001995563507080078
# GENERATIVE Training
# Bias:  0.18335220744106046
# Variance:  0.3083981513197135
# DISCRIMINATIVE Training
# Bias:  0.3433614184042171
# Variance:  0.6751423488518333
#
#
# 26 - th batch of: 100
# Testing Accuracy: 90.1
# Testing Loss: 0.3616696894168854
# Testing Time: 0.002987384796142578
# GENERATIVE Training
# Bias:  0.18558212177327843
# Variance:  0.3128125946647855
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.34296707059628223
# Variance:  0.6711277630925929
#
#
# 27 - th batch of: 100
# Testing Accuracy: 88.3
# Testing Loss: 0.38240137696266174
# Testing Time: 0.003017902374267578
# GENERATIVE Training
# Bias:  0.1876721730106789
# Variance:  0.3202846694054692
# DISCRIMINATIVE Training
# Bias:  0.3418091459516782
# Variance:  0.6672109546716835
#
#
# 28 - th batch of: 100
# Testing Accuracy: 88.1
# Testing Loss: 0.4205695390701294
# Testing Time: 0.002001047134399414
# GENERATIVE Training
# Bias:  0.19001954343499255
# Variance:  0.3276907847876108
# DISCRIMINATIVE Training
# Bias:  0.34158523439278987
# Variance:  0.6619366848930279
#
#
# 29 - th batch of: 100
# Testing Accuracy: 89.6
# Testing Loss: 0.3611670732498169
# Testing Time: 0.002019643783569336
# GENERATIVE Training
# Bias:  0.19209643638574966
# Variance:  0.33432080567300704
# DISCRIMINATIVE Training
# Bias:  0.3409326346809709
# Variance:  0.6560056469617378
#
#
# 30 - th batch of: 100
# Testing Accuracy: 85.3
# Testing Loss: 0.4334465265274048
# Testing Time: 0.003019094467163086
# GENERATIVE Training
# Bias:  0.19407529545445623
# Variance:  0.340652932879909
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.34071915398652364
# Variance:  0.6493820599298658
#
#
# 31 - th batch of: 100
# Testing Accuracy: 87.6
# Testing Loss: 0.4091259241104126
# Testing Time: 0.001987934112548828
# GENERATIVE Training
# Bias:  0.19564798833722719
# Variance:  0.34643106847779254
# DISCRIMINATIVE Training
# Bias:  0.34007653805631066
# Variance:  0.6422994389997781
#
#
# 32 - th batch of: 100
# Testing Accuracy: 88.3
# Testing Loss: 0.3879418969154358
# Testing Time: 0.0019788742065429688
# GENERATIVE Training
# --- Hidden NODE No:  2  is PRUNED ---
# Bias:  0.19717741282018755
# Variance:  0.3507305722560406
# DISCRIMINATIVE Training
# Bias:  0.3391273855161135
# Variance:  0.6345107558703177
#
#
# 33 - th batch of: 100
# Testing Accuracy: 89.6
# Testing Loss: 0.379271537065506
# Testing Time: 0.029866456985473633
# GENERATIVE Training
# Bias:  0.19896360825341483
# Variance:  0.3535883542104067
# DISCRIMINATIVE Training
# Bias:  0.3385158934253158
# Variance:  0.6276572454912943
#
#
# 34 - th batch of: 100
# Testing Accuracy: 87.5
# Testing Loss: 0.3889474868774414
# Testing Time: 0.002003192901611328
# GENERATIVE Training
# Bias:  0.20072209166662364
# Variance:  0.35702431448124483
# DISCRIMINATIVE Training
# Bias:  0.33793186293744043
# Variance:  0.6207742336988642
#
#
# 35 - th batch of: 100
# Testing Accuracy: 89.9
# Testing Loss: 0.3747979700565338
# Testing Time: 0.0020275115966796875
# GENERATIVE Training
# Bias:  0.20215550572747873
# Variance:  0.36059176425364653
# DISCRIMINATIVE Training
# Bias:  0.3373211806978498
# Variance:  0.6146663835814563
#
#
# 36 - th batch of: 100
# Testing Accuracy: 88.3
# Testing Loss: 0.388893187046051
# Testing Time: 0.002020120620727539
# GENERATIVE Training
# Bias:  0.20356170566566303
# Variance:  0.36375358327337665
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.3372355489883632
# Variance:  0.6097652647511065
#
#
# 37 - th batch of: 100
# Testing Accuracy: 80.5
# Testing Loss: 0.4286110997200012
# Testing Time: 0.001997232437133789
# GENERATIVE Training
# Bias:  0.20479506762114585
# Variance:  0.366679567344635
# DISCRIMINATIVE Training
# Bias:  0.33785302445750093
# Variance:  0.6090671441196643
#
#
# 38 - th batch of: 100
# Testing Accuracy: 83.8
# Testing Loss: 0.3959404230117798
# Testing Time: 0.003992795944213867
# GENERATIVE Training
# Bias:  0.20610902299880624
# Variance:  0.36895144914900746
# DISCRIMINATIVE Training
# Bias:  0.3384715363320318
# Variance:  0.6113617198120351
#
#
# 39 - th batch of: 100
# Testing Accuracy: 88.7
# Testing Loss: 0.38655775785446167
# Testing Time: 0.001995086669921875
# GENERATIVE Training
# Bias:  0.20749463130328138
# Variance:  0.3710189860443752
# DISCRIMINATIVE Training
# Bias:  0.33905167250675156
# Variance:  0.6143751256231152
#
#
# 40 - th batch of: 100
# Testing Accuracy: 89.4
# Testing Loss: 0.3864060938358307
# Testing Time: 0.0030069351196289062
# GENERATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.2082104039346235
# Variance:  0.3713516515284839
# DISCRIMINATIVE Training
# Bias:  0.3396703117235311
# Variance:  0.6172960978620599
#
#
# 41 - th batch of: 100
# Testing Accuracy: 88.7
# Testing Loss: 0.38683515787124634
# Testing Time: 0.001985788345336914
# GENERATIVE Training
# Bias:  0.20845923480603315
# Variance:  0.36967603279368283
# DISCRIMINATIVE Training
# Bias:  0.3402716766416439
# Variance:  0.6211461347098662
#
#
# 42 - th batch of: 100
# Testing Accuracy: 89.4
# Testing Loss: 0.3790030777454376
# Testing Time: 0.001995563507080078
# GENERATIVE Training
# Bias:  0.2086295631830902
# Variance:  0.36781875757465754
# DISCRIMINATIVE Training
# Bias:  0.3408260960042516
# Variance:  0.6238876717856955
#
#
# 43 - th batch of: 100
# Testing Accuracy: 87.7
# Testing Loss: 0.3986254632472992
# Testing Time: 0.003991127014160156
# GENERATIVE Training
# Bias:  0.20864294652932489
# Variance:  0.3658276374362563
# DISCRIMINATIVE Training
# Bias:  0.3411806677513277
# Variance:  0.6266476101233942
#
#
# 44 - th batch of: 100
# Testing Accuracy: 89.7
# Testing Loss: 0.39945805072784424
# Testing Time: 0.0009984970092773438
# GENERATIVE Training
# Bias:  0.2087872073336113
# Variance:  0.36413016144223154
# DISCRIMINATIVE Training
# Bias:  0.3416634963785923
# Variance:  0.62934333608433
#
#
# 45 - th batch of: 100
# Testing Accuracy: 86.3
# Testing Loss: 0.43177807331085205
# Testing Time: 0.0030241012573242188
# GENERATIVE Training
# Bias:  0.20879782219169038
# Variance:  0.3622993589174384
# DISCRIMINATIVE Training
# Bias:  0.3421646638074422
# Variance:  0.6313211199522211
#
#
# 46 - th batch of: 100
# Testing Accuracy: 91.2
# Testing Loss: 0.3420187830924988
# Testing Time: 0.002992391586303711
# GENERATIVE Training
# Bias:  0.209016539935091
# Variance:  0.36055589012778083
# DISCRIMINATIVE Training
# Bias:  0.34259248179002627
# Variance:  0.6338316534651126
#
#
# 47 - th batch of: 100
# Testing Accuracy: 89.2
# Testing Loss: 0.3604917824268341
# Testing Time: 0.0029916763305664062
# GENERATIVE Training
# Bias:  0.20899492240918915
# Variance:  0.35873024620036265
# DISCRIMINATIVE Training
# Bias:  0.3429347942147291
# Variance:  0.6363074340925229
#
#
# 48 - th batch of: 100
# Testing Accuracy: 88.1
# Testing Loss: 0.4125899076461792
# Testing Time: 0.003988504409790039
# GENERATIVE Training
# Bias:  0.2092212879404242
# Variance:  0.3571884644840553
# DISCRIMINATIVE Training
# Bias:  0.34338951495731157
# Variance:  0.6385545279051322
#
#
# 49 - th batch of: 100
# Testing Accuracy: 88.6
# Testing Loss: 0.41594022512435913
# Testing Time: 0.0019941329956054688
# GENERATIVE Training
# Bias:  0.2094900674567638
# Variance:  0.3554833506558065
# DISCRIMINATIVE Training
# Bias:  0.34381894571740435
# Variance:  0.6410528568297471
#
#
# 50 - th batch of: 100
# Testing Accuracy: 83.7
# Testing Loss: 0.3128657042980194
# Testing Time: 0.0029952526092529297
# GENERATIVE Training
# Bias:  0.2097091374843066
# Variance:  0.35367329268227554
# DISCRIMINATIVE Training
# Bias:  0.34411495749375387
# Variance:  0.6435565811247078
#
#
# 51 - th batch of: 100
# Testing Accuracy: 97.2
# Testing Loss: 0.1459139585494995
# Testing Time: 0.002021312713623047
# GENERATIVE Training
# Bias:  0.21000816569808772
# Variance:  0.3520346967080935
# DISCRIMINATIVE Training
# Bias:  0.3450319855619786
# Variance:  0.6454657783073711
#
#
# 52 - th batch of: 100
# Testing Accuracy: 99.5
# Testing Loss: 0.12751665711402893
# Testing Time: 0.0019986629486083984
# GENERATIVE Training
# Bias:  0.21020566153977616
# Variance:  0.35037693419640936
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.345574455043021
# Variance:  0.6465633968230071
#
#
# 53 - th batch of: 100
# Testing Accuracy: 99.2
# Testing Loss: 0.12161419540643692
# Testing Time: 0.0030100345611572266
# GENERATIVE Training
# Bias:  0.21078226735377392
# Variance:  0.351465671720736
# DISCRIMINATIVE Training
# Bias:  0.3461211462458056
# Variance:  0.6464650074667505
#
#
# 54 - th batch of: 100
# Testing Accuracy: 99.1
# Testing Loss: 0.10447477549314499
# Testing Time: 0.0029838085174560547
# GENERATIVE Training
# Bias:  0.21149547843535044
# Variance:  0.3524610080862193
# DISCRIMINATIVE Training
# Bias:  0.34716423503905286
# Variance:  0.6449286674959952
#
#
# 55 - th batch of: 100
# Testing Accuracy: 97.1
# Testing Loss: 0.0946921706199646
# Testing Time: 0.0030031204223632812
# GENERATIVE Training
# Bias:  0.212137322891266
# Variance:  0.3531800961608438
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.348408936759312
# Variance:  0.6422517706836748
#
#
# 56 - th batch of: 100
# Testing Accuracy: 98.1
# Testing Loss: 0.09048087894916534
# Testing Time: 0.0039899349212646484
# GENERATIVE Training
# Bias:  0.21273590385193433
# Variance:  0.35404754216081563
# DISCRIMINATIVE Training
# Bias:  0.3494437837167465
# Variance:  0.6389491271512773
#
#
# 57 - th batch of: 100
# Testing Accuracy: 97.3
# Testing Loss: 0.09034445136785507
# Testing Time: 0.002028226852416992
# GENERATIVE Training
# Bias:  0.21325561442618415
# Variance:  0.35485439684615316
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.35029013325008446
# Variance:  0.6347615563623313
#
#
# 58 - th batch of: 100
# Testing Accuracy: 97.3
# Testing Loss: 0.08829787373542786
# Testing Time: 0.0029909610748291016
# GENERATIVE Training
# Bias:  0.21382534701300007
# Variance:  0.3564076818191099
# DISCRIMINATIVE Training
# Bias:  0.3513804471872542
# Variance:  0.6299711632135897
#
#
# 59 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.07832875847816467
# Testing Time: 0.0020194053649902344
# GENERATIVE Training
# Bias:  0.21443245436538638
# Variance:  0.3574877383766012
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.35275277209174716
# Variance:  0.6246679459536871
#
#
# 60 - th batch of: 100
# Testing Accuracy: 99.6
# Testing Loss: 0.0697975605726242
# Testing Time: 0.0030143260955810547
# GENERATIVE Training
# Bias:  0.21498468285337796
# Variance:  0.3588299494842748
# DISCRIMINATIVE Training
# Bias:  0.3537328695141035
# Variance:  0.6193306150057124
#
#
# 61 - th batch of: 100
# Testing Accuracy: 99.7
# Testing Loss: 0.07324226945638657
# Testing Time: 0.003988981246948242
# GENERATIVE Training
# Bias:  0.21566767354417868
# Variance:  0.35965045015085045
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.35526572783848326
# Variance:  0.6139559441139865
#
#
# 62 - th batch of: 100
# Testing Accuracy: 96.5
# Testing Loss: 0.09352308511734009
# Testing Time: 0.003015279769897461
# GENERATIVE Training
# Bias:  0.21606753716460264
# Variance:  0.3598787393235926
# DISCRIMINATIVE Training
# Bias:  0.3565403719572423
# Variance:  0.6117849427976945
#
#
# 63 - th batch of: 100
# Testing Accuracy: 97.1
# Testing Loss: 0.08581708371639252
# Testing Time: 0.002039194107055664
# GENERATIVE Training
# Bias:  0.21651066379108422
# Variance:  0.3597844129079189
# DISCRIMINATIVE Training
# Bias:  0.3577154208163751
# Variance:  0.6135808787992749
#
#
# 64 - th batch of: 100
# Testing Accuracy: 98.9
# Testing Loss: 0.0794866606593132
# Testing Time: 0.001994609832763672
# GENERATIVE Training
# Bias:  0.21699725795775232
# Variance:  0.358927672636003
# DISCRIMINATIVE Training
# Bias:  0.359052769435395
# Variance:  0.615653337327316
#
#
# 65 - th batch of: 100
# Testing Accuracy: 97.9
# Testing Loss: 0.0848192498087883
# Testing Time: 0.0030176639556884766
# GENERATIVE Training
# Bias:  0.21751074301145185
# Variance:  0.35738981168000644
# DISCRIMINATIVE Training
# Bias:  0.36051536818146823
# Variance:  0.6176725181328439
#
#
# 66 - th batch of: 100
# Testing Accuracy: 97.2
# Testing Loss: 0.08202770352363586
# Testing Time: 0.0029850006103515625
# GENERATIVE Training
# Bias:  0.21790092771143904
# Variance:  0.35544834807271736
# DISCRIMINATIVE Training
# Bias:  0.36188297039584466
# Variance:  0.6199433733062794
#
#
# 67 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.0714721605181694
# Testing Time: 0.003025054931640625
# GENERATIVE Training
# Bias:  0.21833101480516348
# Variance:  0.3532706055347697
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.363502891348442
# Variance:  0.6218587158003
#
#
# 68 - th batch of: 100
# Testing Accuracy: 98.7
# Testing Loss: 0.0643031969666481
# Testing Time: 0.003020763397216797
# GENERATIVE Training
# Bias:  0.21866201656405146
# Variance:  0.3497812071739931
# DISCRIMINATIVE Training
# Bias:  0.36499269756319785
# Variance:  0.6230582324927759
#
#
# 69 - th batch of: 100
# Testing Accuracy: 96.1
# Testing Loss: 0.08177794516086578
# Testing Time: 0.0030133724212646484
# GENERATIVE Training
# Bias:  0.21897403218751924
# Variance:  0.34726873219840404
# DISCRIMINATIVE Training
# Bias:  0.36602587116929564
# Variance:  0.6240951449558698
#
#
# 70 - th batch of: 100
# Testing Accuracy: 99.5
# Testing Loss: 0.06206325441598892
# Testing Time: 0.002992391586303711
# GENERATIVE Training
# Bias:  0.2194752832384535
# Variance:  0.345097108161837
# DISCRIMINATIVE Training
# Bias:  0.3675271580500814
# Variance:  0.6255556066731892
#
#
# 71 - th batch of: 100
# Testing Accuracy: 99.4
# Testing Loss: 0.058587174862623215
# Testing Time: 0.003955364227294922
# GENERATIVE Training
# Bias:  0.2199100722600136
# Variance:  0.34244477587362554
# DISCRIMINATIVE Training
# Bias:  0.3688441201292012
# Variance:  0.6265090884510571
#
#
# 72 - th batch of: 100
# Testing Accuracy: 98.7
# Testing Loss: 0.06316255778074265
# Testing Time: 0.0030176639556884766
# GENERATIVE Training
# Bias:  0.22039259088872643
# Variance:  0.3396368305152325
# DISCRIMINATIVE Training
# Bias:  0.37066655259306297
# Variance:  0.6277359170964393
#
#
# 73 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.06512656807899475
# Testing Time: 0.002016782760620117
# GENERATIVE Training
# Bias:  0.2206907325655244
# Variance:  0.3365534971580043
# DISCRIMINATIVE Training
# Bias:  0.3715329972790519
# Variance:  0.6284149989369494
#
#
# 74 - th batch of: 100
# Testing Accuracy: 99.7
# Testing Loss: 0.05561813339591026
# Testing Time: 0.0029904842376708984
# GENERATIVE Training
# Bias:  0.22102184070263825
# Variance:  0.33364573350340576
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.37295423404534006
# Variance:  0.6291332523384604
#
#
# 75 - th batch of: 100
# Testing Accuracy: 85.9
# Testing Loss: 0.355115681886673
# Testing Time: 0.002026796340942383
# GENERATIVE Training
# Bias:  0.221324767428586
# Variance:  0.3306682019683132
# DISCRIMINATIVE Training
# Bias:  0.37267959123614824
# Variance:  0.6211322476840939
#
#
# 76 - th batch of: 100
# Testing Accuracy: 99.2
# Testing Loss: 0.044134471565485
# Testing Time: 0.002992868423461914
# GENERATIVE Training
# Bias:  0.2217935712679515
# Variance:  0.33055083988164097
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.37245962176873393
# Variance:  0.6131439452561406
#
#
# 77 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.04288299009203911
# Testing Time: 0.001995086669921875
# GENERATIVE Training
# Bias:  0.2221754952557397
# Variance:  0.3323360846641021
# DISCRIMINATIVE Training
# Bias:  0.37163161179550175
# Variance:  0.6053431016732902
#
#
# 78 - th batch of: 100
# Testing Accuracy: 99.5
# Testing Loss: 0.03724898025393486
# Testing Time: 0.002991914749145508
# GENERATIVE Training
# Bias:  0.22262174765556658
# Variance:  0.3340857964288597
# DISCRIMINATIVE Training
# Bias:  0.3709680547057912
# Variance:  0.5977248286742727
#
#
# 79 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.046145834028720856
# Testing Time: 0.003992557525634766
# GENERATIVE Training
# Bias:  0.22297897194823704
# Variance:  0.3358490372953236
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.37068929772074405
# Variance:  0.5903103670929892
#
#
# 80 - th batch of: 100
# Testing Accuracy: 99.4
# Testing Loss: 0.040869519114494324
# Testing Time: 0.002982616424560547
# GENERATIVE Training
# Bias:  0.22330296450481305
# Variance:  0.33766379549603553
# DISCRIMINATIVE Training
# Bias:  0.37020980477001686
# Variance:  0.5830595969566391
#
#
# 81 - th batch of: 100
# Testing Accuracy: 98.7
# Testing Loss: 0.04236380383372307
# Testing Time: 0.0029914379119873047
# GENERATIVE Training
# Bias:  0.22362874663671076
# Variance:  0.33946425143718395
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.3698618924362144
# Variance:  0.5759895818223937
#
#
# 82 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.046239662915468216
# Testing Time: 0.00399017333984375
# GENERATIVE Training
# Bias:  0.22409197938401484
# Variance:  0.3411664149681894
# DISCRIMINATIVE Training
# Bias:  0.36991430901011213
# Variance:  0.5690836900743445
#
#
# 83 - th batch of: 100
# Testing Accuracy: 99.5
# Testing Loss: 0.03292592614889145
# Testing Time: 0.0030164718627929688
# GENERATIVE Training
# Bias:  0.22443161071577156
# Variance:  0.3426801156263669
# DISCRIMINATIVE Training
# Bias:  0.36954554458026107
# Variance:  0.5623380689349207
#
#
# 84 - th batch of: 100
# Testing Accuracy: 99.8
# Testing Loss: 0.037482813000679016
# Testing Time: 0.002991199493408203
# GENERATIVE Training
# Bias:  0.2247648484281472
# Variance:  0.3443341607275253
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.36940050205717956
# Variance:  0.5557530626037179
#
#
# 85 - th batch of: 100
# Testing Accuracy: 99.3
# Testing Loss: 0.04338926449418068
# Testing Time: 0.0030181407928466797
# GENERATIVE Training
# Bias:  0.22516373332029188
# Variance:  0.34609009940249397
# DISCRIMINATIVE Training
# Bias:  0.3694893161973369
# Variance:  0.5493150352754526
#
#
# 86 - th batch of: 100
# Testing Accuracy: 99.9
# Testing Loss: 0.03349203243851662
# Testing Time: 0.00301361083984375
# GENERATIVE Training
# Bias:  0.225453606297103
# Variance:  0.3476576722636055
# DISCRIMINATIVE Training
# +++ GROW a hidden NODE +++
# Bias:  0.3691384544095279
# Variance:  0.5430211749338719
#
#
# 87 - th batch of: 100
# Testing Accuracy: 91.0
# Testing Loss: 0.3758200705051422
# Testing Time: 0.002993345260620117
# GENERATIVE Training
# Bias:  0.22572768940895852
# Variance:  0.34909866203614603
# DISCRIMINATIVE Training
# Bias:  0.3701289458954352
# Variance:  0.5373303354328411
#
#
# 88 - th batch of: 100
# Testing Accuracy: 89.7
# Testing Loss: 0.20142817497253418
# Testing Time: 0.003989458084106445
# GENERATIVE Training
# Bias:  0.2260240032793339
# Variance:  0.35050683936228394
# DISCRIMINATIVE Training
# Bias:  0.37070988495802276
# Variance:  0.5360577951837281
#
#
# 89 - th batch of: 100
# Testing Accuracy: 98.0
# Testing Loss: 0.062081217765808105
# Testing Time: 0.0039784908294677734
# GENERATIVE Training
# Bias:  0.22625040098793323
# Variance:  0.3516528334235617
# DISCRIMINATIVE Training
# Bias:  0.3710730478814956
# Variance:  0.5364979072208444
#
#
# 90 - th batch of: 100
# Testing Accuracy: 98.2
# Testing Loss: 0.06753348559141159
# Testing Time: 0.00498652458190918
# GENERATIVE Training
# Bias:  0.2265221509819219
# Variance:  0.3524761939049187
# DISCRIMINATIVE Training
# Bias:  0.3715869698509463
# Variance:  0.5376579762037914
#
#
# 91 - th batch of: 100
# Testing Accuracy: 99.2
# Testing Loss: 0.054169222712516785
# Testing Time: 0.0029909610748291016
# GENERATIVE Training
# Bias:  0.22679924719140793
# Variance:  0.35271599040283097
# DISCRIMINATIVE Training
# Bias:  0.3720179234708812
# Variance:  0.5391642639162851
#
#
# 92 - th batch of: 100
# Testing Accuracy: 99.0
# Testing Loss: 0.047752123326063156
# Testing Time: 0.00498509407043457
# GENERATIVE Training
# Bias:  0.227070826243987
# Variance:  0.35238917931107
# DISCRIMINATIVE Training
# Bias:  0.37260808354659997
# Variance:  0.540742669343416
#
#
# 93 - th batch of: 100
# Testing Accuracy: 99.7
# Testing Loss: 0.05413686856627464
# Testing Time: 0.0039713382720947266
# GENERATIVE Training
# Bias:  0.227403960727842
# Variance:  0.3517341665371385
# DISCRIMINATIVE Training
# Bias:  0.373103005671781
# Variance:  0.5426108041171277
#
#
# 94 - th batch of: 100
# Testing Accuracy: 97.8
# Testing Loss: 0.06292203068733215
# Testing Time: 0.003958225250244141
# GENERATIVE Training
# Bias:  0.22768431088271232
# Variance:  0.350634641759293
# DISCRIMINATIVE Training
# Bias:  0.37360104355177964
# Variance:  0.5446002701995873
#
#
# 95 - th batch of: 100
# Testing Accuracy: 98.9
# Testing Loss: 0.048529934138059616
# Testing Time: 0.0030298233032226562
# GENERATIVE Training
# Bias:  0.22803223960936075
# Variance:  0.3492757816994362
# DISCRIMINATIVE Training
# Bias:  0.3742777804204239
# Variance:  0.5467619869032713
#
#
# 96 - th batch of: 100
# Testing Accuracy: 99.5
# Testing Loss: 0.04731769859790802
# Testing Time: 0.0029914379119873047
# GENERATIVE Training
# Bias:  0.22821114466549355
# Variance:  0.34751450431260444
# DISCRIMINATIVE Training
# Bias:  0.3746393614563792
# Variance:  0.5489253535445471
#
#
# 97 - th batch of: 100
# Testing Accuracy: 97.9
# Testing Loss: 0.05929103121161461
# Testing Time: 0.0020263195037841797
# GENERATIVE Training
# Bias:  0.22845736602481684
# Variance:  0.3456348662623527
# DISCRIMINATIVE Training
# Bias:  0.3750562963516028
# Variance:  0.5512532545045566
#
#
# 98 - th batch of: 100
# Testing Accuracy: 99.1
# Testing Loss: 0.049212392419576645
# Testing Time: 0.0020210742950439453
# GENERATIVE Training
# Bias:  0.22879685506243744
# Variance:  0.34368876747202654
# DISCRIMINATIVE Training
# Bias:  0.37576354022069175
# Variance:  0.5535622767779986
#
#
# 99 - th batch of: 100
# Testing Accuracy: 99.9
# Testing Loss: 0.04780726507306099
# Testing Time: 0.003990888595581055
# GENERATIVE Training
# Bias:  0.2290840918564027
# Variance:  0.34154843742998864
# DISCRIMINATIVE Training
# Bias:  0.3763528435207704
# Variance:  0.555832231680668
#
#
# === FINAL result ===
# Accuracy:  91.54233177542244 (+/-) 8.051928994893103
# Training Time:  3.6254063649475152 (+/-) 0.19033471110294392
# Testing Time:  3.6254063649475152 (+/-) 0.0029873749007267845
# Network structure:

# %%
print(net)
# Out:
# [devdan(
#   (linear): Linear(in_features=3, out_features=22, bias=True)
#   (linearOutput): Linear(in_features=22, out_features=2, bias=True)
#   (activation): Sigmoid()
# )]

# %%
conda list
# Out:
# # packages in environment at C:\Users\SCSE\AppData\Local\Continuum\miniconda3\envs\stmicro:
# #
# # Name                    Version                   Build  Channel
# _tflow_select             2.2.0                     eigen
# absl-py                   0.8.1                    py37_0
# astor                     0.8.0                    py37_0
# attrs                     19.3.0                     py_0
# backcall                  0.1.0                    py37_0
# blas                      1.0                         mkl
# bleach                    3.1.0                    py37_0
# ca-certificates           2020.1.1                      0
# certifi                   2019.11.28               py37_0
# cffi                      1.13.2           py37h7a1dbc1_0
# cloudpickle               1.2.2                    pypi_0    pypi
# colorama                  0.4.3                      py_0
# cudatoolkit               10.1.243             h74a9793_0
# cycler                    0.10.0                   py37_0
# decorator                 4.4.1                      py_0
# defusedxml                0.6.0                      py_0
# entrypoints               0.3                      py37_0
# freetype                  2.9.1                ha9979f8_1
# future                    0.18.2                   pypi_0    pypi
# gast                      0.2.2                    py37_0
# google-pasta              0.1.8                      py_0
# grpcio                    1.16.1           py37h351948d_1
# gym                       0.15.6                   pypi_0    pypi
# h5py                      2.10.0           py37h5e291fa_0
# hdf5                      1.10.4               h7ebc959_0
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha66f8fd_1
# importlib_metadata        1.5.0                    py37_0
# inflect                   4.1.0                    py37_0
# intel-openmp              2020.0                      166
# ipykernel                 5.1.4            py37h39e3cac_0
# ipython                   7.12.0           py37h5ca1d4c_0
# ipython_genutils          0.2.0                    py37_0
# ipywidgets                7.5.1                      py_0
# jaraco.itertools          5.0.0                      py_0
# jedi                      0.16.0                   py37_0
# jinja2                    2.11.1                     py_0
# joblib                    0.14.1                     py_0
# jpeg                      9b                   hb83a4c4_2
# jsonschema                3.2.0                    py37_0
# jupyter                   1.0.0                    py37_7
# jupyter_client            5.3.4                    py37_0
# jupyter_console           6.1.0                      py_0
# jupyter_core              4.6.1                    py37_0
# keras                     2.2.4                         0
# keras-applications        1.0.8                      py_0
# keras-base                2.2.4                    py37_0
# keras-preprocessing       1.1.0                      py_1
# kiwisolver                1.1.0            py37ha925a31_0
# libpng                    1.6.37               h2a8f88b_0
# libprotobuf               3.11.2               h7bd577a_0
# libsodium                 1.0.16               h9d3ae62_0
# libtiff                   4.1.0                h56a325e_0
# m2w64-gcc-libgfortran     5.3.0                         6
# m2w64-gcc-libs            5.3.0                         7
# m2w64-gcc-libs-core       5.3.0                         7
# m2w64-gmp                 6.1.0                         2
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2
# markdown                  3.1.1                    py37_0
# markupsafe                1.1.1            py37he774522_0
# matplotlib                3.1.3                    py37_0
# matplotlib-base           3.1.3            py37h64f37c6_0
# mistune                   0.8.4            py37he774522_0
# mkl                       2020.0                      166
# mkl-service               2.3.0            py37hb782905_0
# mkl_fft                   1.0.15           py37h14836fe_0
# mkl_random                1.1.0            py37h675688f_0
# more-itertools            8.2.0                      py_0
# msys2-conda-epoch         20160418                      1
# nbconvert                 5.6.1                    py37_0
# nbformat                  5.0.4                      py_0
# networkx                  2.4                        py_0
# ninja                     1.9.0            py37h74a9793_0
# notebook                  6.0.3                    py37_0
# numpy                     1.18.1           py37h93ca92e_0
# numpy-base                1.18.1           py37hc3f5095_1
# olefile                   0.46                     py37_0
# openssl                   1.1.1d               he774522_3
# opt_einsum                3.1.0                      py_0
# pandas                    1.0.0            py37h47e9c7a_0
# pandoc                    2.2.3.2                       0
# pandocfilters             1.4.2                    py37_1
# parso                     0.6.0                      py_0
# pickleshare               0.7.5                    py37_0
# pillow                    7.0.0            py37hcc1f983_0
# pip                       20.0.2                   py37_1
# progressbar               2.5                      pypi_0    pypi
# prometheus_client         0.7.1                      py_0
# prompt_toolkit            3.0.3                      py_0
# protobuf                  3.11.2           py37h33f27b4_0
# pycparser                 2.19                     py37_0
# pyglet                    1.4.10                   pypi_0    pypi
# pygments                  2.5.2                      py_0
# pyparsing                 2.4.6                      py_0
# pyqt                      5.9.2            py37h6538335_2
# pyreadline                2.1                      py37_1
# pyrsistent                0.15.7           py37he774522_0
# python                    3.7.6                h60c2a47_2
# python-dateutil           2.8.1                      py_0
# pytorch                   1.4.0           py3.7_cuda101_cudnn7_0    pytorch
# pytz                      2019.3                     py_0
# pywin32                   227              py37he774522_1
# pywinpty                  0.5.7                    py37_0
# pyyaml                    5.3              py37he774522_0
# pyzmq                     18.1.1           py37ha925a31_0
# qt                        5.9.7            vc14h73c81de_0
# qtconsole                 4.6.0                      py_1
# scikit-learn              0.22.1           py37h6288b17_0
# scipy                     1.4.1            py37h9439919_0
# seaborn                   0.10.0                     py_0
# send2trash                1.5.0                    py37_0
# setuptools                45.1.0                   py37_0
# sip                       4.19.8           py37h6538335_0
# six                       1.14.0                   py37_0
# sqlite                    3.31.1               he774522_0
# tensorboard               2.0.0              pyhb38c66f_1
# tensorflow                1.15.0          eigen_py37h9f89a44_0
# tensorflow-base           1.15.0          eigen_py37h07d2309_0
# tensorflow-estimator      1.15.1             pyh2649769_0
# termcolor                 1.1.0                    py37_1
# terminado                 0.8.3                    py37_0
# testpath                  0.4.4                      py_0
# tk                        8.6.8                hfa6e2cd_0
# torchvision               0.5.0                    pypi_0    pypi
# tornado                   6.0.3            py37he774522_1
# traitlets                 4.3.3                    py37_0
# vc                        14.1                 h0510ff6_4
# vs2015_runtime            14.16.27012          hf0eaf9b_1
# wcwidth                   0.1.8                      py_0
# webencodings              0.5.1                    py37_1
# werkzeug                  0.16.1                     py_0
# wheel                     0.34.2                   py37_0
# widgetsnbextension        3.5.1                    py37_0
# wincertstore              0.2                      py37_0
# winpty                    0.4.3                         4
# wrapt                     1.11.2           py37he774522_0
# xz                        5.2.4                h2fa13f4_4
# yaml                      0.1.7                hc54c509_2
# zeromq                    4.3.1                h33f27b4_3
# zipp                      2.1.0                      py_0
# zlib                      1.2.11               h62dcd97_3
# zstd                      1.3.7                h508b16e_0
#
# Note: you may need to restart the kernel to use updated packages.
